# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Load and inspect the dataset
df = pd.read_csv('house_price_data.csv')
print(df.head())
print(df.isnull().sum())

# Visualize correlations between features
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")
plt.show()

# Split data into features (X) and target (y)
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# Train the Linear Regression model
lm = LinearRegression()
lm.fit(X_train, y_train)

# Display the model's intercept and coefficients
print(lm.intercept_)
coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
print(coeff_df)

# Make predictions and plot actual vs predicted values
predictions = lm.predict(X_test)
plt.scatter(y_test, predictions)
# Out:
#    Square Footage  Bedrooms  Bathrooms  House Age         Price
# 0            1360         2          1         37  5.264547e+05
# 1            4272         2          4         50  1.492402e+06
# 2            3592         4          4         53  1.378069e+06
# 3             966         5          3          7  6.250518e+05
# 4            4926         3          2         26  1.698204e+06
# Square Footage    0
# Bedrooms          0
# Bathrooms         0
# House Age         0
# Price             0
# dtype: int64
# 1917.4880829225294
#                  Coefficient
# Square Footage    299.762002
# Bedrooms        50231.090328
# Bathrooms       30367.032399
# House Age        -236.161503
